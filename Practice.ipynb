# %%
import wordcloud
from PIL import Image
from numpy import array
from wordcloud import WordCloud
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
im=Image.open("./love-mask.png")
width,height = im.size
back=Image.new("RGB",im.size,"white")
back.paste(im,(0,0));

names ='''
Nomaswati
Joanne
Yasmin
Nomel
Anita
Bobbie
Bryan 
Amon 
Lazare 
Clarence
Rachel
Henry 
Anda 
Manzi  
Alia
Ruth  
Neima 
Roseline 
Chenai 
Milembo
Uwase 
Ruth 
Charles 
Franc 
BEKONO 
Miyanda 
Sharon 
Julia 
Marie 
Ahab
Abdulrahman
Suzana
Kibo  
Pamela 
kulwa 
Owen
Massa 
Nancy 
Yao  
Tadiwanashi 
Judith 
Francisco
Salvador 
John 
Chioni 
Helen 
Vanelle 
Lisa 
Mary 
Jackline 
Suzana 
Mbonea 
Merveil 
Christian 
Eric 
Michelle
Justino 
Emmanuel
Mcnally
Arsen 
Henry 
Tukwaje 
Sephora
Nency
Chidera
Yves 
Vanessa
Lasme  
Kouakou
Ako Nomel Haymes Axel-Elie Junior
'''


colors='''
Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, inferno, inferno_r, jet, jet_r, magma, magma_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, seismic, seismic_r, spectral, spectral_r, spring, spring_r, summer, summer_r, terrain, terrain_r, viridis, viridis_r, winter, winter_r
'''
#colors=colors.strip().split(',')
display(back)
mask=array(back)

from wordcloud import WordCloud
data = WordCloud(font_path="./Lobster-Regular.ttf",
                 width=width,
                 min_font_size=10,
                 max_font_size=50,
                 max_words=1000,
                 height=height,
                repeat=True,
                colormap="hot_r",
                 mask=mask)

display(data.generate(names).to_image())
del data, WordCloud
    #plt.imshow(data, interpolation='bilinear')
#plt.axis("off")
#plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=600x534 at 0x7F68764A1E80>
# <PIL.Image.Image image mode=RGB size=600x534 at 0x7F68764A1748>

# %%
import zipfile
zip_ref = zipfile.ZipFile("./new.zip", 'r')
zip_ref.extractall("./")
zip_ref.close()

# %%
print(d)
# Out:
# ['Accent', ' Accent_r', ' Blues', ' Blues_r', ' BrBG', ' BrBG_r', ' BuGn', ' BuGn_r', ' BuPu', ' BuPu_r', ' CMRmap', ' CMRmap_r', ' Dark2', ' Dark2_r', ' GnBu', ' GnBu_r', ' Greens', ' Greens_r', ' Greys', ' Greys_r', ' OrRd', ' OrRd_r', ' Oranges', ' Oranges_r', ' PRGn', ' PRGn_r', ' Paired', ' Paired_r', ' Pastel1', ' Pastel1_r', ' Pastel2', ' Pastel2_r', ' PiYG', ' PiYG_r', ' PuBu', ' PuBuGn', ' PuBuGn_r', ' PuBu_r', ' PuOr', ' PuOr_r', ' PuRd', ' PuRd_r', ' Purples', ' Purples_r', ' RdBu', ' RdBu_r', ' RdGy', ' RdGy_r', ' RdPu', ' RdPu_r', ' RdYlBu', ' RdYlBu_r', ' RdYlGn', ' RdYlGn_r', ' Reds', ' Reds_r', ' Set1', ' Set1_r', ' Set2', ' Set2_r', ' Set3', ' Set3_r', ' Spectral', ' Spectral_r', ' Wistia', ' Wistia_r', ' YlGn', ' YlGnBu', ' YlGnBu_r', ' YlGn_r', ' YlOrBr', ' YlOrBr_r', ' YlOrRd', ' YlOrRd_r', ' afmhot', ' afmhot_r', ' autumn', ' autumn_r', ' binary', ' binary_r', ' bone', ' bone_r', ' brg', ' brg_r', ' bwr', ' bwr_r', ' cool', ' cool_r', ' coolwarm', ' coolwarm_r', 
# ...

# %%
# !git clone https://github.com/uberwach/leveling-up-jupyter.git
# Out:
# Cloning into 'leveling-up-jupyter'...
# remote: Enumerating objects: 93, done.
# remote: Total 93 (delta 0), reused 0 (delta 0), pack-reused 93
# Unpacking objects: 100% (93/93), done.
# Checking connectivity... done.

# %%
# %config IPCompleter.greedy=True

# %%
# !wget http://images.clipartpanda.com/white-heart-black-background-biyMz59iL.png -O love-mask.png
# Out:
# --2019-06-04 10:33:30--  http://images.clipartpanda.com/white-heart-black-background-biyMz59iL.png
# Resolving images.clipartpanda.com (images.clipartpanda.com)... 52.216.128.107
# Connecting to images.clipartpanda.com (images.clipartpanda.com)|52.216.128.107|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12910 (13K) []
# Saving to: ‘love-mask.png’
#
# love-mask.png       100%[===================>]  12.61K  --.-KB/s    in 0.02s
#
# 2019-06-04 10:33:30 (571 KB/s) - ‘love-mask.png’ saved [12910/12910]

# %%
import p5
dir(p5)
# Out:
# WARNING: Could not load OpenGL library.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-c8ed1853f3e4> in <module>
# ----> 1 import p5
#       2 dir(p5)
#
# ~/.local/lib/python3.5/site-packages/p5/__init__.py in <module>
#      17 #
#      18
# ---> 19 from .sketch import *
#      20 from .core import *
#      21 from .pmath import *
#
# ~/.local/lib/python3.5/site-packages/p5/sketch/__init__.py in <module>
#      17 #
#      18 import vispy
# ---> 19 vispy.use('glfw')
#      20
#      21 from .userspace import *
#
# ~/.local/lib/python3.5/site-packages/vispy/util/wrappers.py in use(app, gl)
#      94     if app:
#      95         from ..app import use_app
# ---> 96         use_app(app)
#      97
#      98
#
# ~/.local/lib/python3.5/site-packages/vispy/app/_default_app.py in use_app(backend_name, call_reuse)
#      45
#      46     # Create default app
# ...
