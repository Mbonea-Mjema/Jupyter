# %%
# !wget https://image.flaticon.com/icons/png/512/69/69904.png
# Out:
# --2019-05-24 10:49:02--  https://image.flaticon.com/icons/png/512/69/69904.png
# Resolving image.flaticon.com (image.flaticon.com)... 23.35.178.61, 2600:1409:3000:4af::30ec, 2600:1409:3000:48a::30ec
# Connecting to image.flaticon.com (image.flaticon.com)|23.35.178.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4827 (4.7K) [image/png]
# Saving to: ‘69904.png’
#
# 69904.png           100%[===================>]   4.71K  --.-KB/s    in 0s
#
# 2019-05-24 10:49:02 (815 MB/s) - ‘69904.png’ saved [4827/4827]

# %%
import wordcloud
from PIL import Image
from numpy import array
from wordcloud import WordCloud
im=Image.open("69904.png")
width,height = im.size
back=Image.new("RGB",im.size,"white")
back.paste(im,(0,0));

names ='''
Nomaswati
Joanne
Yasmin essa
Nomel
Anita
Bobbie
Bryan Mudeza
Amon Chikohora
Lazare ilungs
Clarence Ali
Henry mukaz
Anda napo
Manzi John 
Alia
Ruth .T. Chadehumbe 
Neima Gugulethu Moyo
Roseline tombotiya
Chenai Chikono
Milembo
Uwase Godelive
Ruth Mubwangolo
Charles kpoghomou
Franc kevin
BEKONO WILLY
Miyanda Shamba
Sharon Deepika
Julia Bock
Marie Ida Lidji
Ahab
Abdulrahman
Suzana
Kibo Stephen Simbila 
Pamela namong John
kulwa 
Owen.E.K
Massa Auriola
Nancy 
Yao kuoadio 
Tadiwanashi Benhura
Judith mugisa
Francisco
Salvador Muteb
John Banze
Chioni malama
Helen Mubita
Vanelle Mikombe
Lisa Catherine
Mary Yamat
Jackline Kunoi
Suzana kuboja
Mbonea Godwin
Merveil Ngongo Ntambwe
Christian kambale
Eric Cibanvunya
Michelle Manale
Justino Goma
Emmanuel Anuwe
Mcnally
Arsen Useni
Henry kabeke
Tukwaje Victoria
Muteb sephora
Nency Bitohi
Chidera
Yves alain
Vanessa
Lasme didier Charles 
Kouakou_adjoua_océane_emmanuella
Ako Nomel Haymes Axel-Elie Junior
'''
mask = array(back)
data = WordCloud(font_path="./Righteous-Regular.ttf",
                 width=width,
                 min_font_size=2,
                 max_font_size=50, 
                 max_words=100,
                 height=height,
                 mask=mask,
                 background_color="white").generate(names)
display(data.to_image())

#plt.imshow(data, interpolation='bilinear')
#plt.axis("off")
#plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FC43307D668>

# %%
# !wget http://www.3benefitsof.com/wp-content/uploads/2014/07/the-holy-bible.jpg
# Out:
# --2019-05-23 19:21:22--  http://www.3benefitsof.com/wp-content/uploads/2014/07/the-holy-bible.jpg
# Resolving www.3benefitsof.com (www.3benefitsof.com)... 66.96.160.129
# Connecting to www.3benefitsof.com (www.3benefitsof.com)|66.96.160.129|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46667 (46K) [image/jpeg]
# Saving to: ‘the-holy-bible.jpg’
#
# the-holy-bible.jpg  100%[===================>]  45.57K   185KB/s    in 0.2s
#
# 2019-05-23 19:21:22 (185 KB/s) - ‘the-holy-bible.jpg’ saved [46667/46667]

# %%
import zipfile
zip_ref = zipfile.ZipFile("./font.zip", 'r')
zip_ref.extractall("./")
zip_ref.close()
